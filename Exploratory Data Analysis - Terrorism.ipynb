# %% [markdown]
# # Exploratory Data Analysis - Terrorism
# ### Name : Sachin Mishra

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = "globalterrorismdbdist.csv"
data = pd.read_csv(url,encoding="latin1")
print("Data imported successfully")

data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Data imported successfully
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %% [markdown]
# ### Data Insights

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
data.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# <h4>All Columns</h4>

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
terror_data = data[['iyear','imonth','iday','country_txt','region_txt','provstate','city','attacktype1_txt','gname','weaptype1_txt','targtype1_txt','weapdetail','nkill','nwound','summary']]

# %%
terror_data.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city                 attacktype1_txt  \
# 0       NaN  Santo Domingo                   Assassination
# 1   Federal    Mexico city     Hostage Taking (Kidnapping)
# 2    Tarlac        Unknown                   Assassination
# 3    Attica         Athens               Bombing/Explosion
# 4   Fukouka        Fukouka  Facility/Infrastructure Attack
#
#                                 gname weaptype1_txt  \
# 0                              MANO-D       Unknown
# 1  23rd of September Communist League       Unknown
# ...

# %%
terror_data.isnull().sum()
# Out:
# iyear                  0
# imonth                 0
# iday                   0
# country_txt            0
# region_txt             0
# provstate            421
# city                 434
# attacktype1_txt        0
# gname                  0
# weaptype1_txt          0
# targtype1_txt          0
# weapdetail         67670
# nkill              10313
# nwound             16311
# summary            66129
# dtype: int64

# %% [markdown]
# ## Country With Most Terror Activities

# %%
terror_data['country_txt'].value_counts().head()
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: country_txt, dtype: int64

# %%
plt.figure(figsize=(30,12))
sns.countplot('country_txt', data=terror_data)
plt.title('Country With Most Terrorist activities',fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(terror_data['country_txt'].value_counts()[:10].index, terror_data['country_txt'].value_counts()[:10].values)
plt.show()

# %% [markdown]
# <h5>These are the top 10 Countries with Most Terror activities. Iraq at top</h5>

# %% [markdown]
# <h2>Terrorist attack Per Year</h2>

# %%
plt.figure(figsize=(30,12))
sns.countplot('iyear', data=terror_data)
plt.xlabel("Year",fontsize=25)
plt.ylabel("Attack Count",fontsize=25)
plt.title('Terrorist Attack Per Year',fontsize=40)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4><i>Above Graph show us, in year 2014 most terrorist attack was carried out.</i></h4>

# %% [markdown]
# <h2>People Killed in Terror Attack</h2>

# %%
df = terror_data[['iyear','nkill']].groupby('iyear').sum()
fig,ax4 = plt.subplots(figsize=(20,6))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.title("People Killed Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %% [markdown]
# <h4><i>From Above the graph most people were killed in 2014.</i></h4>

# %% [markdown]
# <h2>Weapons Used</h2>

# %%
plt.figure(figsize=(15,6))
sns.countplot('weaptype1_txt', data=terror_data)
plt.xlabel("Weapons",fontsize=15)
plt.ylabel("Attack Count",fontsize=15)
plt.title('Weapons Used',fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4>Explosive was the most common weapons used in terror attacks.</h4>

# %% [markdown]
# <h2>Region with Maximum Attack</h2>

# %%
plt.figure(figsize=(15,6))
sns.countplot('region_txt', data=terror_data)
plt.xlabel("Place",fontsize=15)
plt.ylabel("Attack Count",fontsize=15)
plt.title('Target Site',fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4><i>Middle East and North Africa Region were most of Attack took Place.</i></h4>

# %% [markdown]
# <h2><b>Most Target Place</b></h2>

# %%
plt.figure(figsize=(15,6))
sns.countplot(terror_data['targtype1_txt'], order = terror_data['targtype1_txt'].value_counts().index)
plt.xlabel("Region",fontsize=15)
plt.ylabel("Attack Count",fontsize=15)
plt.title('Region with Maximum Attack',fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4><i>Private Citizens and Propert are most target Site of Terrorist</i><h4>

# %% [markdown]
# <h2>Organisation Involved In Attacks</h2>

# %%
plt.figure(figsize=(8,6))
sns.barplot(terror_data['gname'].value_counts()[:15].values, terror_data['gname'].value_counts()[:15].index)
plt.xlabel("Attack Count",fontsize=15)
plt.ylabel("Groups",fontsize=15)
plt.title('Terror Organisation',fontsize=30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4><i>Terror Organisation with most Terror attacks is Taliban</i></h4>

# %% [markdown]
# <h2>Hot Zone of Terrorism</h2>

# %%
plt.figure(figsize=(15,6))
sns.barplot(terror_data['city'].value_counts()[:15].index, terror_data['city'].value_counts()[:15].values)
plt.xlabel("City",fontsize=15)
plt.ylabel("Attack Count",fontsize=15)
plt.title('Hot zone of terrorism.',fontsize=35)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h4><i>From above graph Baghdad and Karachi are the hot zone of terrorism.</i></h4>

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Country with Most Terror Activities: Iraq
# - Year with Most Terror Activities: 2014
# - People Killed  Most in Year : 2014
# - Weapons  Used during Terror Activities: Explosivies
# - Region with Most Terror Attacks: Middle East and North Africa
# - Most Target Plcae: Private Citizens and Property
# - Group with the most attacks: Taliban
# - City with the most attacks: Baghdad
